# %%
# LISTS #

# %%
# Create a list of 5 fruits. Print the 2nd item, then the last item using negative indexing.

# %%
fruits = ['apple', 'banana', 'cherry', 'orange', 'lemon']

# %%
fruits[1]
# Out:
# 'banana'

# %%
fruits[-1]
# Out:
# 'lemon'

# %%
# Add "mango" to the end of the list, then remove "banana" from it.

# %%
fruits.append('mango')

# %%
fruits.remove('banana')

# %%
fruits.pop(2)
# Out:
# 'orange'

# %%
fruits
# Out:
# ['apple', 'cherry', 'lemon', 'mango']

# %%
# Given nums = [4, 1, 8, 3, 9], sort it in ascending order, then print it reversed.

# %%
numbers = [4, 1, 8, 3, 9]

# %%
numbers.sort()
numbers
# Out:
# [1, 3, 4, 8, 9]

# %%
numbers.sort(reverse = True)
numbers
# Out:
# [9, 8, 4, 3, 1]

# %%
# Use a for loop to print each item in your fruit list with its index (hint: look up enumerate).

# %%
for index, fruit in enumerate(fruits):
  print(index, fruit)
# Out:
# 0 apple
# 1 cherry
# 2 orange
# 3 lemon
# 4 mango

# %%
# DICTIONARIES #

# %%
# 5. Create a dictionary for a person with keys name, age, city. Print just the age.

# %%
person = {
    'name': 'John',
    'age': 18,
    'city': 'Urgench'
}

# %%
person['age']
# Out:
# 18

# %%
person.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
# 6. Add a new key job to that dictionary. Then update age to a new value.

# %%
person['last_name'] = 'Wick'

# %%
person['age'] = 19

# %%
person.update({'name': 'Johnny'})

# %%
person
# Out:
# {'name': 'Johnny', 'age': 19, 'city': 'Urgench', 'last_name': 'Wick'}

# %%
# 7. Loop through the dictionary and print each key and value together.

# %%
for key, values in person.items():
  print(key, values)
# Out:
# name Johnny
# age 19
# city Urgench
# last_name Wick

# %%
# 8. Check if the key "email" exists in the dictionary before trying to access it (avoid a crash).

# %%
'email' in person
# Out:
# False

# %%
# SETS #

# %%
# 9. Create two sets: set1 = {1,2,3,4} and set2 = {3,4,5,6}. Print their union, intersection, and difference.

# %%
set1 = {1,2,3,4}

# %%
set2 = {3,4,5,6}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.intersection(set2)
# Out:
# {3, 4}

# %%
set1.difference(set2)
# Out:
# {1, 2}

# %%
set2.difference(set1)
# Out:
# {5, 6}

# %%
# Mixed
# 13. Create a dictionary where each key is a person's name and the value is a list of their favorite foods. Print one person's full food list.

# %%
dict = {
    'John': ['Interstellar', 'Inception', 'Momento'],
    'Jura': ['Substance', 'Matrix'],
    'Humayun': ['F&F', 'Avengers']
}

# %%
dict['Jura']
# Out:
# ['Substance', 'Matrix']
