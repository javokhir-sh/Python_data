# %%
### LIBRARIES ###

# %%
# NUMPY #

# %%
import random
random.randint(100,200)
# Out:
# 182

# %%
salary_list = [random.randint(50000, 100000) for _ in range(1000000)]

# %%
import statistics
statistics.mean(salary_list)
# Out:
# 74994.635071

# %%
# %%timeit
statistics.mean(salary_list)
# Out:
# The slowest run took 6.32 times longer than the fastest. This could mean that an intermediate result is being cached.
# 618 ms ± 465 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np
np.mean(salary_list)
# Out:
# np.float64(74994.635071)

# %%
# %%timeit
np.mean(salary_list)
# Out:
# 247 ms ± 77.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
my_array = np.array([1,2,3,4,])

# %%
my_array
# Out:
# array([1, 2, 3, 4])

# %%
my_array.mean()
# Out:
# np.float64(2.5)

# %%
job_titles = np.array (['Data analyst', 'Data scientist', 'Data engineer', 'AI'])
base_salaries = np.array ([60000, 80000, 75000, 90000])
bonus_rates = np.array ([.05, .1, .08, .12])

# %%
total_salaries = base_salaries * (bonus_rates +1)
total_salaries
# Out:
# array([ 63000.,  88000.,  81000., 100800.])

# %%
np.mean(total_salaries)
# Out:
# np.float64(83200.0)

# %%
None

# %%
type(None)
# Out:
# NoneType

# %%
type(np.nan)
# Out:
# float

# %%
job_titles = np.array (['Data analyst', 'Data scientist', 'Data engineer', 'AI', 'BI anayst'])
base_salaries = np.array ([60000, 80000, 75000, 90000, np.nan])
bonus_rates = np.array ([.05, .1, .08, .12, np.nan])

# %%
total_salaries = base_salaries * (bonus_rates +1)
total_salaries
# Out:
# array([ 63000.,  88000.,  81000., 100800.,     nan])

# %%
np.nanmean(total_salaries)
# Out:
# np.float64(83200.0)

# %%
## PANDAS #######

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['total_rooms']
# Out:
# 0       3885.0
# 1       1510.0
# 2       3589.0
# 3         67.0
# 4       1241.0
#          ...
# 2995    1450.0
# 2996    5257.0
# 2997     956.0
# 2998      96.0
# 2999    1765.0
# Name: total_rooms, Length: 3000, dtype: float64

# %%
df['total_rooms'][0]
# Out:
# np.float64(3885.0)

# %%
# !pip install datasets

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/3.25k [00:00<?, ?B/s]
# data_jobs.csv: reconstructing file:   0%|          |  0.00B /  231MB
# data_jobs.csv: downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['job_title_short', 'job_title', 'job_location', 'job_via', 'job_schedule_type', 'job_work_from_home', 'search_location', 'job_posted_date', 'job_no_degree_mention', 'job_health_insurance', 'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg', 'company_name', 'job_skills', 'job_type_skills'],
#         num_rows: 785741
#     })
# })

# %%
dataset['train']
# Out:
# Dataset({
#     features: ['job_title_short', 'job_title', 'job_location', 'job_via', 'job_schedule_type', 'job_work_from_home', 'search_location', 'job_posted_date', 'job_no_degree_mention', 'job_health_insurance', 'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg', 'company_name', 'job_skills', 'job_type_skills'],
#     num_rows: 785741
# })

# %%
type(dataset['train'])
# Out:
# datasets.arrow_dataset.Dataset

# %%
dataset['train'].to_pandas()
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df = dataset['train'].to_pandas()

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df.head(7)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
#
#                    job_location             job_via         job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby                 Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México                 Full-time
# 2               Berlin, Germany        via LinkedIn                 Full-time
# ...

# %%
df.tail()
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# ...

# %%
df['job_location'].head()
# Out:
# 0                   Watertown, CT
# 1    Guadalajara, Jalisco, Mexico
# 2                 Berlin, Germany
# 3                 San Antonio, TX
# 4                  Washington, DC
# Name: job_location, dtype: object

# %%
df[['job_health_insurance']]
# Out:
#         job_health_insurance
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ...                      ...
# 785736                 False
# 785737                 False
# 785738                 False
# 785739                 False
# 785740                 False
#
# [785741 rows x 1 columns]

# %%
df[['job_health_insurance', 'job_location']]
# Out:
#         job_health_insurance                         job_location
# 0                      False                        Watertown, CT
# 1                      False         Guadalajara, Jalisco, Mexico
# 2                      False                      Berlin, Germany
# 3                      False                      San Antonio, TX
# 4                      False                       Washington, DC
# ...                      ...                                  ...
# 785736                 False                            Singapura
# 785737                 False                   Bad Rodach, Jerman
# 785738                 False                             Malaysia
# 785739                 False  Newark, New Jersey, Amerika Serikat
# 785740                 False                                India
#
# [785741 rows x 2 columns]

# %%
df[['job_health_insurance', 'job_location']].head()
# Out:
#    job_health_insurance                  job_location
# 0                 False                 Watertown, CT
# 1                 False  Guadalajara, Jalisco, Mexico
# 2                 False               Berlin, Germany
# 3                 False               San Antonio, TX
# 4                 False                Washington, DC

# %%
df.iloc[90]  #  shows row 90 info
# Out:
# job_title_short                                             Data Scientist
# job_title                                                   Data Scientist
# job_location                                                     Australia
# job_via                                                via BeBee Australia
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                  Australia
# job_posted_date                                        2023-11-25 13:12:03
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                      Australia
# salary_rate                                                           None
# ...

# %%
df.iloc[90:96]
# Out:
#    job_title_short                                     job_title  \
# 90  Data Scientist                                Data Scientist
# 91  Data Scientist                                Data Scientist
# 92   Data Engineer       Remote - Data Engineer - Permanent - W2
# 93    Data Analyst  IT Finance / TBM Data Analyst - Remote | WFH
# 94   Data Engineer              Data Engineer - Cloud Operations
# 95   Data Engineer                                 Data Engineer
#
#                   job_location                         job_via  \
# 90                   Australia             via BeBee Australia
# 91               Temuco, Chile                 via BeBee Chile
# 92                    Anywhere                    via LinkedIn
# 93                    Anywhere                    via LinkedIn
# 94                    Lehi, UT                    via LinkedIn
# 95  Mumbai, Maharashtra, India  via Crimsoniteam.freshteam.com
#
# ...

# %%
df.iloc[90:96, 0]  # info for rows 90-95 in the 1st column
# Out:
# 90    Data Scientist
# 91    Data Scientist
# 92     Data Engineer
# 93      Data Analyst
# 94     Data Engineer
# 95     Data Engineer
# Name: job_title_short, dtype: object

# %%
df.iloc[90:96, 0:3]  # for columns 1 2 3
# Out:
#    job_title_short                                     job_title  \
# 90  Data Scientist                                Data Scientist
# 91  Data Scientist                                Data Scientist
# 92   Data Engineer       Remote - Data Engineer - Permanent - W2
# 93    Data Analyst  IT Finance / TBM Data Analyst - Remote | WFH
# 94   Data Engineer              Data Engineer - Cloud Operations
# 95   Data Engineer                                 Data Engineer
#
#                   job_location
# 90                   Australia
# 91               Temuco, Chile
# 92                    Anywhere
# 93                    Anywhere
# 94                    Lehi, UT
# 95  Mumbai, Maharashtra, India

# %%
df [['job_title_short', 'job_title']].iloc[90:96]
# Out:
#    job_title_short                                     job_title
# 90  Data Scientist                                Data Scientist
# 91  Data Scientist                                Data Scientist
# 92   Data Engineer       Remote - Data Engineer - Permanent - W2
# 93    Data Analyst  IT Finance / TBM Data Analyst - Remote | WFH
# 94   Data Engineer              Data Engineer - Cloud Operations
# 95   Data Engineer                                 Data Engineer

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_title_short.unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df.job_title_short == 'Data Analyst'
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737     True
# 785738    False
# 785739    False
# 785740    False
# Name: job_title_short, Length: 785741, dtype: bool

# %%
df[df.job_title_short == 'Data Analyst']
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
df[(df.job_title_short == 'Data Analyst') & (df.salary_year_avg > 100000)]
# Out:
#        job_title_short                                      job_title  \
# 410       Data Analyst    IT Business Lead Data Analyst - VP - Hybrid
# 1555      Data Analyst                  Data Analyst/Engineer (M/F/D)
# 1681      Data Analyst                                   Data Analyst
# 1684      Data Analyst                       Data Analyst - Data17829
# 1867      Data Analyst  Data Integration Analyst (West Coast/Chicago)
# ...                ...                                            ...
# 783588    Data Analyst                         Data Analytics Manager
# 783866    Data Analyst                Lead Credit Bureau Data Analyst
# 784033    Data Analyst                       Recruitment Data Analyst
# 785187    Data Analyst                                   Data Analyst
# 785515    Data Analyst                                   Data Analyst
#
#                        job_location               job_via job_schedule_type  \
# ...

# %%
df[(df.job_title_short == 'Data Analyst') | (df.salary_year_avg > 100000)]
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 28      Data Scientist                                CRM Data Specialist
# 31        Data Analyst                           Stage - Data Analyst F/H
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                                    job_location  \
# ...

# %%
df.salary_year_avg.notna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: salary_year_avg, Length: 785741, dtype: bool

# %%
df[(df.job_title_short == 'Data Analyst') & (df.salary_year_avg.notna())]
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 784033    Data Analyst                     Recruitment Data Analyst
# 784423    Data Analyst                           Sales Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
# 785187    Data Analyst                                 Data Analyst
# 785515    Data Analyst                                 Data Analyst
#
#                        job_location                job_via job_schedule_type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.job_posted_date.dt.month
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_date, Length: 785741, dtype: int32

# %%
df['job_posted_date'] = df.job_posted_date.dt.month

# %%
df.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  int32
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
print(df['job_posted_date'].iloc[0])
print(type(df['job_posted_date'].iloc[0]))
# Out:
# 1970-01-01 00:00:00.000000006
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df['job_posted_date'].head()
# Out:
# 0   1970-01-01 00:00:00.000000006
# 1   1970-01-01 00:00:00.000000001
# 2   1970-01-01 00:00:00.000000010
# 3   1970-01-01 00:00:00.000000007
# 4   1970-01-01 00:00:00.000000008
# Name: job_posted_date, dtype: datetime64[ns]

# %%
pd.to_datetime(df.job_posted_date)
# Out:
# 0        1970-01-01 00:00:00.000000006
# 1        1970-01-01 00:00:00.000000001
# 2        1970-01-01 00:00:00.000000010
# 3        1970-01-01 00:00:00.000000007
# 4        1970-01-01 00:00:00.000000008
#                       ...
# 785736   1970-01-01 00:00:00.000000003
# 785737   1970-01-01 00:00:00.000000003
# 785738   1970-01-01 00:00:00.000000003
# 785739   1970-01-01 00:00:00.000000003
# 785740   1970-01-01 00:00:00.000000003
# Name: job_posted_date, Length: 785741, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.sort_values('job_posted_date')
# Out:
#                   job_title_short                          job_title  \
# 203943             Data Scientist                     Data Scientist
# 282667             Data Scientist                     Data Scientist
# 93472        Senior Data Engineer               Senior Data Engineer
# 93471              Data Scientist                  Data Scientist II
# 282665             Data Scientist    Material Data Specialist(Coupa)
# ...                           ...                                ...
# 413720             Data Scientist              Data Science- GPT/LLM
# 731675       Senior Data Engineer               Senior Data Engineer
# 467337          Software Engineer    Principal iOS Software Engineer
# 731685  Machine Learning Engineer  Machine-Learning-Engineer (m/w/d)
# 573693           Business Analyst                        QA Engineer
#
#                                          job_location            job_via  \
# ...

# %%
df = df.sort_values('job_posted_date')

# %%
df.sort_values('job_posted_date', inplace=True)

# %%
df
# Out:
#               job_title_short  \
# 203943         Data Scientist
# 709496          Data Engineer
# 709492  Senior Data Scientist
# 709486          Data Engineer
# 30379     Senior Data Analyst
# ...                       ...
# 320501      Software Engineer
# 765254      Software Engineer
# 439849   Senior Data Engineer
# 447335         Data Scientist
# 573693       Business Analyst
#
#                                                 job_title  \
# 203943                                     Data Scientist
# 709496                                      Data Engineer
# 709492  AIML - Senior Data Scientist - Siri and Inform...
# 709486                                      Data Engineer
# 30379          General Assurance Data Analytics – Manager
# ...                                                   ...
# 320501                           Junior Software Engineer
# 765254           Onsite Network Security Support Engineer
# 439849                               Senior Data Engineer
# ...

# %%
df.sort_values('job_posted_date', ascending = False)
# Out:
#                   job_title_short  \
# 573693           Business Analyst
# 92428                Data Analyst
# 237788  Machine Learning Engineer
# 731659             Cloud Engineer
# 644005          Software Engineer
# ...                           ...
# 93472        Senior Data Engineer
# 282667             Data Scientist
# 93461            Business Analyst
# 524112             Data Scientist
# 203943             Data Scientist
#
#                                           job_title  \
# 573693                                  QA Engineer
# 92428                   SAP Data Analyst (Contract)
# 237788                    Machine Learning Engineer
# 731659                             Senior Engineers
# 644005                        Graduate Coding Coach
# ...                                             ...
# 93472                          Senior Data Engineer
# 282667                               Data Scientist
# 93461   Business IT Analyst (Part Time / Full Time)
# ...

# %%
df.drop(labels='job_posted_date', axis = 1)  # removes info for column - when given name its column
# Out:
#               job_title_short  \
# 203943         Data Scientist
# 709496          Data Engineer
# 709492  Senior Data Scientist
# 709486          Data Engineer
# 30379     Senior Data Analyst
# ...                       ...
# 320501      Software Engineer
# 765254      Software Engineer
# 439849   Senior Data Engineer
# 447335         Data Scientist
# 573693       Business Analyst
#
#                                                 job_title  \
# 203943                                     Data Scientist
# 709496                                      Data Engineer
# 709492  AIML - Senior Data Scientist - Siri and Inform...
# 709486                                      Data Engineer
# 30379          General Assurance Data Analytics – Manager
# ...                                                   ...
# 320501                           Junior Software Engineer
# 765254           Onsite Network Security Support Engineer
# 439849                               Senior Data Engineer
# ...

# %%
df.drop(labels=5, axis=0)  # removes info for row 5 - when given numbers its rows
# Out:
#               job_title_short  \
# 203943         Data Scientist
# 709496          Data Engineer
# 709492  Senior Data Scientist
# 709486          Data Engineer
# 30379     Senior Data Analyst
# ...                       ...
# 320501      Software Engineer
# 765254      Software Engineer
# 439849   Senior Data Engineer
# 447335         Data Scientist
# 573693       Business Analyst
#
#                                                 job_title  \
# 203943                                     Data Scientist
# 709496                                      Data Engineer
# 709492  AIML - Senior Data Scientist - Siri and Inform...
# 709486                                      Data Engineer
# 30379          General Assurance Data Analytics – Manager
# ...                                                   ...
# 320501                           Junior Software Engineer
# 765254           Onsite Network Security Support Engineer
# 439849                               Senior Data Engineer
# ...

# %%
df.drop(labels=5)   # axis =1 = column ; axis = 0 - row ------- optional
# Out:
#               job_title_short  \
# 203943         Data Scientist
# 709496          Data Engineer
# 709492  Senior Data Scientist
# 709486          Data Engineer
# 30379     Senior Data Analyst
# ...                       ...
# 320501      Software Engineer
# 765254      Software Engineer
# 439849   Senior Data Engineer
# 447335         Data Scientist
# 573693       Business Analyst
#
#                                                 job_title  \
# 203943                                     Data Scientist
# 709496                                      Data Engineer
# 709492  AIML - Senior Data Scientist - Siri and Inform...
# 709486                                      Data Engineer
# 30379          General Assurance Data Analytics – Manager
# ...                                                   ...
# 320501                           Junior Software Engineer
# 765254           Onsite Network Security Support Engineer
# 439849                               Senior Data Engineer
# ...

# %%
df.dropna(subset = 'salary_year_avg')     # drops na values in given column
# Out:
#                   job_title_short  \
# 30380                Data Analyst
# 709819               Data Analyst
# 709506              Data Engineer
# 710079             Data Scientist
# 710182               Data Analyst
# ...                           ...
# 165424              Data Engineer
# 82064               Data Engineer
# 320672  Machine Learning Engineer
# 156517               Data Analyst
# 447359             Data Scientist
#
#                                                 job_title  \
# 30380   SQL DEVELOPER / DATA ANALYST (Insurance indust...
# 709819     Business/Data Analyst Manager- AVP -C12-Hybrid
# 709506                        Principal Big Data Engineer
# 710079                                     Data Scientist
# 710182                                Junior Data Analyst
# ...                                                   ...
# 165424                                      Data Engineer
# 82064                                   Sr. Data Engineer
# ...

# %%
df.describe()  # --- #  overal statistical values
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg
# count                         785741     22003.000000     10662.000000
# mean   1970-01-01 00:00:00.000000006    123286.274072        47.016598
# min    1970-01-01 00:00:00.000000001     15000.000000         8.000000
# 25%    1970-01-01 00:00:00.000000003     90000.000000        27.500000
# 50%    1970-01-01 00:00:00.000000006    115000.000000        45.980000
# 75%    1970-01-01 00:00:00.000000009    150000.000000        61.159996
# max    1970-01-01 00:00:00.000000012    960000.000000       391.000000
# std                              NaN     48312.449482        21.890738

# %%
df.count()  # total values in each column
# Out:
# job_title_short          785741
# job_title                785740
# job_location             784696
# job_via                  785733
# job_schedule_type        773074
# job_work_from_home       785741
# search_location          785741
# job_posted_date          785741
# job_no_degree_mention    785741
# job_health_insurance     785741
# job_country              785692
# salary_rate               33067
# salary_year_avg           22003
# salary_hour_avg           10662
# company_name             785723
# job_skills               668704
# job_type_skills          668704
# dtype: int64

# %%
df['salary_year_avg'].median()
# Out:
# 115000.0

# %%
df['salary_year_avg'].min()
# Out:
# 15000.0

# %%
min_salary = df['salary_year_avg'].idxmin()

# %%
df.iloc[min_salary]    # shows the calculated min salary in certain value for 1 row with all column names
# Out:
# job_title_short                           Data Analyst
# job_title                   Institutional Data Analyst
# job_location                            Romeoville, IL
# job_via                             via Higher Ed Jobs
# job_schedule_type                            Full-time
# job_work_from_home                               False
# search_location                Illinois, United States
# job_posted_date          1970-01-01 00:00:00.000000011
# job_no_degree_mention                            False
# job_health_insurance                             False
# job_country                              United States
# salary_rate                                       None
# salary_year_avg                                    NaN
# salary_hour_avg                                    NaN
# company_name                          Lewis University
# job_skills                                        None
# job_type_skills                                   None
# Name: 306649, dtype: object

# %%
df['job_title_short'].value_counts()    # shows number of diff values in column
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
df.groupby('job_title_short')['salary_year_avg'].min()    # 1st ([]) value, then [[]] value
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby(['job_title_short', 'job_country'])['salary_year_avg'].min()
# Out:
# job_title_short    job_country
# Business Analyst   Afghanistan        NaN
#                    Albania            NaN
#                    Algeria            NaN
#                    Angola             NaN
#                    Argentina      63000.0
#                                    ...
# Software Engineer  Venezuela          NaN
#                    Vietnam        28000.0
#                    Yemen              NaN
#                    Zambia             NaN
#                    Zimbabwe           NaN
# Name: salary_year_avg, Length: 1387, dtype: float64

# %%
df.groupby('job_title_short')[['salary_year_avg', 'salary_hour_avg']].min()
# Out:
#                            salary_year_avg  salary_hour_avg
# job_title_short
# Business Analyst                   16500.0           10.835
# Cloud Engineer                     42000.0           18.500
# Data Analyst                       25000.0            8.000
# Data Engineer                      15000.0            8.000
# Data Scientist                     27000.0            8.000
# Machine Learning Engineer          30000.0           10.000
# Senior Data Analyst                30000.0           13.000
# Senior Data Engineer               35000.0           12.500
# Senior Data Scientist              45000.0           17.500
# Software Engineer                  28000.0           11.000

# %%
df.groupby('job_title_short')['salary_year_avg'].agg(['min', 'max', 'mean'])
# Out:
#                                min       max           mean
# job_title_short
# Business Analyst           16500.0  387460.0   91082.612833
# Cloud Engineer             42000.0  280000.0  111268.453846
# Data Analyst               25000.0  650000.0   93841.907854
# Data Engineer              15000.0  525000.0  130125.604250
# Data Scientist             27000.0  960000.0  135988.837171
# Machine Learning Engineer  30000.0  325000.0  126774.315972
# Senior Data Analyst        30000.0  425000.0  113911.363665
# Senior Data Engineer       35000.0  425000.0  145840.611624
# Senior Data Scientist      45000.0  890000.0  154206.292996
# Software Engineer          28000.0  375000.0  113393.760054

# %%
print(df['job_posted_date'].iloc[0])
# Out:
# 1970-01-01 00:00:00.000000001
