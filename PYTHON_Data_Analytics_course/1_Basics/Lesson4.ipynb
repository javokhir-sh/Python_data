# %%
# !pip install datasets

# %%
import pandas as pd

from datasets import load_dataset

# %%
d_set = load_dataset('lukebarousse/data_jobs')
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/3.25k [00:00<?, ?B/s]
# data_jobs.csv: reconstructing file:   0%|          |  0.00B /  231MB
# data_jobs.csv: downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
d_set
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['job_title_short', 'job_title', 'job_location', 'job_via', 'job_schedule_type', 'job_work_from_home', 'search_location', 'job_posted_date', 'job_no_degree_mention', 'job_health_insurance', 'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg', 'company_name', 'job_skills', 'job_type_skills'],
#         num_rows: 785741
#     })
# })

# %%
df = d_set['train'].to_pandas()

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df['job_country'].value_counts().head()
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Name: count, dtype: int64

# %%
df['job_country'].isin(['Brazil'])    # ([''])  checks if Brazil in rows (True/False)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: job_country, Length: 785741, dtype: bool

# %%
df['job_country'].isin(['Brazil']).any()  # checks if it actually is in
# Out:
# np.True_

# %%
df['job_country'].isin(['North Korea']).any()
# Out:
# np.False_

# %%
df['job_country'] == 'United States'    # shows T/F for each column abt US
# Out:
# 0          True
# 1         False
# 2         False
# 3          True
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: job_country, Length: 785741, dtype: bool

# %%
df[df['job_country'] == 'United States']     # shows only rows for us
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
us_jobs = df[df['job_country'] == 'United States']
us_jobs
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
us_jobs['salary_year_avg'].notna()   # shows not nan values
# Out:
# 0         False
# 3         False
# 5         False
# 6         False
# 9         False
#           ...
# 785673    False
# 785685    False
# 785692     True
# 785703    False
# 785705    False
# Name: salary_year_avg, Length: 206292, dtype: bool

# %%
us_jobs = us_jobs[us_jobs['salary_year_avg'].notna()]

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].count()
# Out:
# job_title_short
# Business Analyst              431
# Cloud Engineer                 20
# Data Analyst                 4350
# Data Engineer                2915
# Data Scientist               4553
# Machine Learning Engineer     128
# Senior Data Analyst           913
# Senior Data Engineer         1058
# Senior Data Scientist        1241
# Software Engineer             157
# Name: salary_year_avg, dtype: int64

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].agg(['mean', 'median', 'max', 'min']).sort_values('median', ascending = False)
# Out:
#                                     mean    median       max      min
# job_title_short
# Senior Data Scientist      159330.432029  155000.0  475000.0  55000.0
# Machine Learning Engineer  154240.382812  150000.0  315000.0  44408.5
# Senior Data Engineer       151448.023186  150000.0  375000.0  45000.0
# Data Scientist             139946.707204  130000.0  960000.0  30000.0
# Software Engineer          137964.929588  130000.0  375000.0  48982.0
# Data Engineer              134226.676753  125000.0  525000.0  23496.0
# Cloud Engineer             120090.900000  116100.0  221844.0  42000.0
# Senior Data Analyst        115729.129954  110000.0  425000.0  35360.0
# Business Analyst            96175.447397   90000.0  387460.0  35000.0
# Data Analyst                94553.964924   90000.0  375000.0  25000.0
