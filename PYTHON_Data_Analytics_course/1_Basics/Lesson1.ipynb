# %%
# GETTING STARTED  ########################################

# %%
"This is a coding cell"
# Out:
# 'This is a coding cell'

# %%
'This is a coding cell with 1 quote side'
# Out:
# 'This is a coding cell with 1 quote side'

# %%
2+2
3*2
# Out:
# 6

# %%
print(2+2)
print(3*2)
# Out:
# 4
# 6

# %%
print(2+2)
3*2
# Out:
# 4
# 6

# %%
# This is a comment

# %%
2*4 # multiplying by 4
# Out:
# 8

# %% [markdown]
# This is a markdown
#
# # Heading
# ## Heading
# ### Heading
#
# 1. one
# 2. two
# 3. three
#
# **markdown**
#
# ***markdown***
#
# [Here you can put a web address](https://datanerd.tech/)

# %%
# !ls
# Out:
# sample_data

# %%
# %timeit [i**2 for i in range (1000)]
# Out:
# 71.4 µs ± 871 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit
L = []
for n in range (1000):
  L.append(n**2)
# Out:
# 78.8 µs ± 1.03 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# VARIABLES ######################################

# %%
variable_name = 'value'

# %%
salary = 10000
salary
# Out:
# 10000

# %%
print(salary)
# Out:
# 10000

# %%
base_salary = 10000
bonus_rate = .01

# %%
Total_salary = (base_salary * (bonus_rate + 1))
Total_salary
# Out:
# 10100.0

# %%
company_name = 'Data witch.2'
company_name
# Out:
# 'Data witch.2'

# %%
job_wtf = True
job_wtf
# Out:
# True

# %%
job_id = 1
job_title = 'Data analyst'
job_salary = 125000

# %%
print('Data job description')
print('********************')


print('Job_id:       ', job_id)
print('Job_title:    ', job_title )
print('Job_salary:   ', job_salary)
print('Company_name: ', company_name)
print('Job_wtf:      ', job_wtf)
# Out:
# Data job description
# ********************
# Job_id:        1
# Job_title:     Data analyst
# Job_salary:    125000
# Company_name:  Data witch.2
# Job_wtf:       True

# %%
salary = 1000

# %%
salary
# Out:
# 1000

# %%
1000
# Out:
# 1000

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
type(1000)
# Out:
# int

# %%
type('Data analyst')
# Out:
# str

# %%
help(str)

# %%
id(salary)
# Out:
# 137474613421360

# %%
id(job_title)
# Out:
# 137474610748016

# %%
job_1 = 'Data analyst'
job_2 = 'Data analyst'

id(job_1), id(job_2)
# Out:
# (137474610699504, 137474610706800)

# %%
job_3 = job_1

id(job_3), id(job_1)
# Out:
# (137474610699504, 137474610699504)

# %%
print('Supp ma nigga')
# Out:
# Supp ma nigga

# %%
myprint_func = print

# %%
myprint_func('Supp ma nigga')
# Out:
# Supp ma nigga

# %%
def say_hi():
  return'Watcha hallouu'

# %%
say_hi()
# Out:
# 'Watcha hallouu'

# %%
# DATA TYPES  ####################################

# %%
'Data ' + 'Nerd'
# Out:
# 'Data Nerd'

# %%
'data nerd'.capitalize()
# Out:
# 'Data nerd'

# %%
job_id = 102
type(job_id)
# Out:
# int

# %%
job_id = float(103)
type(job_id)
# Out:
# float

# %%
skill = 'Python'
type(skill)
# Out:
# str

# %%
skill.upper()
# Out:
# 'PYTHON'

# %%
skill.lower()
# Out:
# 'python'

# %%
'Python'.lower()
# Out:
# 'python'

# %%
str.lower('Python')
# Out:
# 'python'

# %%
skill
# Out:
# 'Python'

# %%
skill.replace('P', 'J')
# Out:
# 'Jython'

# %%
job_title = 'Data analyst' # rename Data with Doto

# %%
job_title.replace('a', 'o', 2)  # 2 is the count limit to not affect the rest part
# Out:
# 'Doto analyst'

# %%
job_title
# Out:
# 'Data analyst'

# %%
job_title.split(sep=' ', maxsplit=1)
# Out:
# ['Data', 'analyst']

# %%
job_title.split(sep=' ', maxsplit=3)
# Out:
# ['Data', 'analyst']

# %%
# maxsplit - max number of splits starting from the left
# default -1  - no limits

# %%
str.__add__('Data', ' Analyst')
# Out:
# 'Data Analyst'

# %%
'Data'.__add__(' Analyst')
# Out:
# 'Data Analyst'

# %%
'Data' + ' Analyst'
# Out:
# 'Data Analyst'

# %%
"Data analyst; " * 10
# Out:
# 'Data analyst; Data analyst; Data analyst; Data analyst; Data analyst; Data analyst; Data analyst; Data analyst; Data analyst; Data analyst; '

# %%
len('Data analyst')
# Out:
# 12

# %%
### STRING FORMATTING  ##################################################################

# %%
role = 'Data analyst'
skill = 'Python'

# %%
'Role: ' + role
# Out:
# 'Role: Data analyst'

# %%
# htcjg
# frwfesrf
# gsrgsg
# ergsers
# ctrl + /   -   select all to be comment

# %%
'Role: {}'.format(role)
# Out:
# 'Role: Data analyst'

# %%
'Role: {}; Skill required: {}'.format(role, skill)
# Out:
# 'Role: Data analyst; Skill required: Python'

# %%
'Role: {role}; Skill required: {skill}'.format(role=role, skill=skill)
# Out:
# 'Role: Data analyst; Skill required: Python'

# %%
f'Role: {role}; Skill required: {skill}'
# Out:
# 'Role: Data analyst; Skill required: Python'

# %%
'Role: %s' % (role)
# Out:
# 'Role: Data analyst'

# %%
'Role: %s; Skill required: %s' % (role, skill)
# Out:
# 'Role: Data analyst; Skill required: Python'

# %%
years_experience = '965865784'

# %%
'; '.join(years_experience)
# Out:
# '9; 6; 5; 8; 6; 5; 7; 8; 4'

# %%
skills = ['Pyhton', 'SQL', 'Tableau']
type(skills)
# Out:
# list

# %%
'; '.join(skills)
# Out:
# 'Pyhton; SQL; Tableau'

# %%
###  OPERATORS  #######################################################

# %%
2 + 3.0
# Out:
# 5.0

# %%
3.0 - 2
# Out:
# 1.0

# %%
'Whats ' + 'up' + '!'
# Out:
# 'Whats up!'

# %%
('Whats ' + 'up' '? ') * 3
# Out:
# 'Whats up? Whats up? Whats up? '

# %%
10/4  # division
# Out:
# 2.5

# %%
10//4
# Out:
# 2

# %%
11//4   # only full number
# Out:
# 2

# %%
11%4  # remainder
# Out:
# 3

# %%
4 - 2
# Out:
# 2

# %%
four = 4

# %%
four.__sub__(2)
# Out:
# 2

# %%
min_salary = 10.0_000    # . and _ are ignored in numbers
max_salary = 25000_0

# %%
avg_salary = (min_salary + max_salary) / 2
avg_salary
# Out:
# 125005.0

# %%
app1 = 'Joshua'
app2 = 'Kimmich'
app1, app2
# Out:
# ('Joshua', 'Kimmich')

# %%
temp_app = app1

# %%
app1 = app2
app2 = temp_app

# %%
app1, app2
# Out:
# ('Kimmich', 'Joshua')

# %%
app1, app2 = app2, app1

# %%
app1, app2
# Out:
# ('Joshua', 'Kimmich')

# %%
x= 1

# %%
x= x+2
x
# Out:
# 3

# %%
x+=2
x
# Out:
# 7

# %%
x*=3
x
# Out:
# 21

# %%
1 == 1
# Out:
# True

# %%
salary_j = 100.0_34
salary_k = 3456.12
salary_j, salary_k
# Out:
# (100.034, 3456.12)

# %%
salary_j == salary_k
# Out:
# False

# %%
## CONDITIONAL OPERATORS  ##########################################################

# %%
if True:
  print('supp dude')
# Out:
# supp dude

# %%
if False:
  print('fucku buddy')

# %%
if True:
# print('meee')  # must be at least 1 space after comma
              print('mee')
# Out:
# mee

# %%
job_skill = 'sql'
app_skill = 'sql'

# %%
if job_skill and app_skill:
  print('hired')
# Out:
# hired

# %%
if job_skill == app_skill:
  print('matched')
# Out:
# matched

# %%
job_skill = 'Python'
app_skill = 'SQL'
years_exp = 4

if job_skill == app_skill:
  print('skills match')
elif years_exp >= 5:
  print('enough exp')
else:
  print('fucked off')
# Out:
# fucked off

# %%
job_skill = 'Python'
app_skill = 'SQL'
years_exp = 4
company = 'Amazon'

if job_skill == app_skill:
  print('skills match')
elif years_exp >= 5:
  print('enough exp')
elif company == 'Google':
  print('nice cand')
elif app_skill == 'SQL':
  print('SQL adv')
else:
  print('fucked off')
# Out:
# SQL adv

# %%
if app_skill != job_skill:
  print('not a nica matcha')
# Out:
# not a nica matcha

# %%
if app_skill != job_skill:
  pass     #  if not sure what to put yet

# %%
if app_skill == job_skill:
  ...  # same above

# %%
# LISTS  #########################################################

# %%
mylist = [2, 'Jupyter', [7, 'cristiano' ]]
mylist
# Out:
# [2, 'Jupyter', [7, 'cristiano']]

# %%
job_skills = ['Excel', 'SQL', 'Tableau', 'Python']
job_skills
# Out:
# ['Excel', 'SQL', 'Tableau', 'Python']

# %%
job_skills.append('Power BI')
job_skills
# Out:
# ['Excel', 'SQL', 'Tableau', 'Python', 'Power BI']

# %%
job_skills.remove('Tableau')

# %%
job_skills
# Out:
# ['Excel', 'SQL', 'Python', 'Power BI']

# %%
len('Python')
# Out:
# 6

# %%
len(job_skills)
# Out:
# 4

# %%
job_skills[2]
# Out:
# 'Python'

# %%
job_skills.insert(1, 'Azure')

# %%
job_skills
# Out:
# ['Excel', 'Azure', 'SQL', 'Python', 'Power BI']

# %%
job_skills.pop()    # removes the last
# Out:
# 'Power BI'

# %%
job_skills
# Out:
# ['Excel', 'Azure', 'SQL', 'Python']

# %%
job_skills.pop(1)
# Out:
# 'Azure'

# %%
job_skills
# Out:
# ['Excel', 'SQL', 'Python']

# %%
job_skills.append('Azure')   # to the last

# %%
job_skills.insert(2, 'Tableau')

# %%
job_skills
# Out:
# ['Excel', 'SQL', 'Tableau', 'Python', 'Azure']

# %%
job_skills[0:5]
# Out:
# ['Excel', 'SQL', 'Tableau', 'Python', 'Azure']

# %%
job_skills [0:4]     # starting - inclusive; ending - exclusive
# Out:
# ['Excel', 'SQL', 'Tableau', 'Python']

# %%
job_skills[:]   # same all the values as the putting nothing in the original
# Out:
# ['Excel', 'SQL', 'Tableau', 'Python', 'Azure']

# %%
job_skills[::1]   #  also same above but with steps in DEFAULT value 1
# Out:
# ['Excel', 'SQL', 'Tableau', 'Python', 'Azure']

# %%
job_skills[::2]  # with step 2, 1st element then 3 and 5
# Out:
# ['Excel', 'Tableau', 'Azure']

# %%
job_skills[0]
# Out:
# 'Excel'

# %%
job_skills[0:1]
# Out:
# ['Excel']

# %%
job_skills[:1]
# Out:
# ['Excel']

# %%
job_skills[::3]  # 1st element then 4th
# Out:
# ['Excel', 'Python']

# %%
job_skills[::5]  # 1st and 6th
# Out:
# ['Excel']

# %%
my_skills = ['r', 'access', 'excel', 'sql', 'python']
new_skills = ['word', 'docs', 'sheets']

# %%
all_skills = my_skills + new_skills
all_skills
# Out:
# ['r', 'access', 'excel', 'sql', 'python', 'word', 'docs', 'sheets']

# %%
all_skills[7:]
# Out:
# ['sheets']

# %%
all_skills[::3]
# Out:
# ['r', 'sql', 'docs']

# %%
all_skills[-1]  # the last one
# Out:
# 'sheets'

# %%
new_skills = ['word', 'docs', 'sheets']

# %%
skill_1, skill_2, skill_3 = new_skills
print(skill_1)
print(skill_2)
print(skill_3)
# Out:
# word
# docs
# sheets

# %%
new_skills = ['word', 'docs', 'sheets', 'slides']
skill_1, skill_2, *skill_3 = new_skills   # * for all the rest
print(skill_1)
print(skill_2)
print(skill_3)
# Out:
# word
# docs
# ['sheets', 'slides']

# %%
## DICTIONARIES  #####################################################

# %%
{'Database': 'Postgresql'}     # 'key': 'value'
# Out:
# {'Database': 'Postgresql'}

# %%
{4: ['python', 3]}     # key can either be string or integer but not list; value can be any data type
# Out:
# {4: ['python', 3]}

# %%
type({4: ['python', 3]})
# Out:
# dict

# %%
{'info': [['python'], 'string', [1, 2, 7], 19, (3,0)]}
# Out:
# {'info': [['python'], 'string', [1, 2, 7], 19, (3, 0)]}

# %%
job_type_skills = {
    'Database': 'Postgresql',
    'Language': 'Python',
    'Library': 'Pandas'
}

# %%
job_type_skills
# Out:
# {'Database': 'Postgresql', 'Language': 'Python', 'Library': 'Pandas'}

# %%
job_type_skills['Language']  # calling by the key
# Out:
# 'Python'

# %%
job_type_skills.keys()
# Out:
# dict_keys(['Database', 'Language', 'Library'])

# %%
job_type_skills.values()
# Out:
# dict_values(['Postgresql', 'Python', 'Pandas'])

# %%
job_type_skills.pop('Library')
# Out:
# 'Pandas'

# %%
job_type_skills
# Out:
# {'Database': 'Postgresql', 'Language': 'Python'}

# %%
job_type_skills.update({'Cloud': 'Google cloud'})    # adding new

# %%
job_type_skills
# Out:
# {'Database': 'Postgresql', 'Language': 'Python', 'Cloud': 'Google cloud'}

# %%
job_type_skills['Version control'] = 'Git'    # another way of adding element

# %%
job_type_skills
# Out:
# {'Database': 'Postgresql',
#  'Language': 'Python',
#  'Cloud': 'Google cloud',
#  'Version control': 'Git'}

# %%
# keys cannot be duplicated in dictionaries, but in values they can be

# %%
### SETS  ######################################################################

# %%
## unlike LISTS, SETS use {}, main usage: for unique records

# %%
job_skills = {'SQL', 'Python', 'Excel', 'Tableau'}

# %%
job_skills    # sets also alphabetize
# Out:
# {'Excel', 'Python', 'SQL', 'Tableau'}

# %%
type(job_skills)
# Out:
# set

# %%
job_skills.add('R')

# %%
job_skills
# Out:
# {'Excel', 'Python', 'R', 'SQL', 'Tableau'}

# %%
job_skills.add('Python')   # same value adding runs, but actually doesnt add cuz of uniqueness

# %%
job_skills
# Out:
# {'Excel', 'Python', 'R', 'SQL', 'Tableau'}

# %%
job_skills.pop()  # randomly removes
# Out:
# 'Excel'

# %%
job_skills.remove('R')   # specifically removing

# %%
job_skills
# Out:
# {'Python', 'SQL', 'Tableau'}

# %%
skill_list = ['Python', 'SQL', 'Tableau', 'SQL']

# %%
type(skill_list)
# Out:
# list

# %%
set(skill_list)     # makes the list to a set, removing duplicates
# Out:
# {'Python', 'SQL', 'Tableau'}

# %%
list(set(skill_list))    # back to list, but duplicates are not back
# Out:
# ['SQL', 'Python', 'Tableau']

# %%
## TUPLES  #################################

# %%
## used for FIXED VALUES - immutable
# unlike lists, it uses ()

# %%
j_skill = ('Python', 'SQL', 'R', 'Access')

# %%
print(j_skill)
# Out:
# ('Python', 'SQL', 'R', 'Access')

# %%
type(j_skill)
# Out:
# tuple

# %%
j_skill[1]
# Out:
# 'SQL'

# %%
j_skill[0:2]
# Out:
# ('Python', 'SQL')

# %%
new_skills = ('Word', 'Power BI')

# %%
j_skill += new_skills   # adds new_skills value to j_skill

# %%
j_skill
# Out:
# ('Python', 'SQL', 'R', 'Access', 'Word', 'Power BI')

# %%
j_skill = ('Python', 'SQL', 'R', 'Access')
print(id(j_skill))

new_skills = ('Word', 'Power BI')
j_skill+= new_skills
id(j_skill)
# Out:
# 135246142893936
# 135246142751456

# %%
range(5)
# Out:
# range(0, 5)

# %%
tuple(range(5))
# Out:
# (0, 1, 2, 3, 4)

# %%
tuple(range(1, 20, 3))
# Out:
# (1, 4, 7, 10, 13, 16, 19)

# %%
job_from_home = True
job_health_insurance = False
job_experience = True

# %%
job_from_home and job_health_insurance
# Out:
# False

# %%
not True
# Out:
# False

# %%
job_from_home or job_health_insurance
# Out:
# True

# %%
job_from_home or job_health_insurance and job_experience     # job_exp must be true
# Out:
# True

# %%
job_from_home or job_health_insurance and not job_experience    # job_exp must not be true
# Out:
# True

# %%
## exp above

# 1. not job_experience - job_experience must not be True = must be False: but its True so its 'False'
# 2. job_health_insurance and [that] - False and False = False
# 3. job_from_home or [those] - True or False = True
# or: at least 1 side True -> True

# %%
if job_from_home or job_health_insurance and not job_experience:
  print('aw shit here we go again')
# Out:
# aw shit here we go again

# %%
'Data' in 'Data nerd'
# Out:
# True

# %%
'data' in 'Data nerd'
# Out:
# False

# %%
job_skills = ['Python', 'SQL', 'R']

# %%
"R" in job_skills
# Out:
# True

# %%
"R" not in job_skills
# Out:
# False

# %%
salary_k = 1000
salary_j = 1000

# %%
salary_k == salary_j
# Out:
# True

# %%
salary_k is salary_j
# Out:
# False

# %%
print(id(salary_k))
id(salary_j)
# Out:
# 135246142953712
# 135246142960688

# %%
id(salary_k) == id(salary_j)
# Out:
# False

# %%
core_skills = ['R', 'Pyhon', 'SQL']
myskills = core_skills

# %%
core_skills is myskills
# Out:
# True

# %%
print(id(core_skills))
id(myskills)
# Out:
# 135246144125120
# 135246144125120

# %%
## LOOPS #####################################

# %%
s_skills = ('Python', 'SQL', 'R', 'Access', 'Word', 'Power BI')

# %%
len(s_skills)
# Out:
# 6

# %%
p_list = []

for skill in s_skills:
  if "P" in skill:
    p_list.append(skill)

# if a skill in s_skills has P, will be added to new list called p_list

# %%
p_list
# Out:
# ['Python', 'Power BI']

# %%
numbers = [0, 1, 2,3 ,4 ,5 ]

# %%
for number in numbers:     # number - variable; numbers - iterable; both variable and iterable are just randomly assigned
  print(number)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
aword = 'Python'
for pic in aword:
  print(pic)
# Out:
# P
# y
# t
# h
# o
# n

# %%
years_exp = {
    'Luke': 4,
    'Kennedy': 2,
    'Johhny': 3,
    'Kalish': 2
}

# %%
type(years_exp)
# Out:
# dict

# %%
for p in years_exp:
  print(p)

# only displays the keys
# Out:
# Luke
# Kennedy
# Johhny
# Kalish

# %%
for ghfh in years_exp.values():
  print(ghfh)
# Out:
# 4
# 2
# 3
# 2

# %%
for tyj in years_exp.items():
  print(tyj)

# if written as 1 variable, shows like a tuple
# Out:
# ('Luke', 4)
# ('Kennedy', 2)
# ('Johhny', 3)
# ('Kalish', 2)

# %%
for tyj, ftyj in years_exp.items():
  print(tyj, ftyj)

# if written as 2 variables, shows normally
# Out:
# Luke 4
# Kennedy 2
# Johhny 3
# Kalish 2

# %%
for key, value in years_exp.items():
  if value > 3:
    print(key, 'has', value, 'years of exp')
# Out:
# Luke has 4 years of exp

# %%
years_exp = {
    'Luke': 4,
    'Kennedy': 2,
    'Johhny': 3,
    'Kalish': 2,
    'Josh': 7
}

# %%
type(years_exp)
# Out:
# dict

# %%
list_years = list(years_exp.items())
list_years
# Out:
# [('Luke', 4), ('Kennedy', 2), ('Johhny', 3), ('Kalish', 2), ('Josh', 7)]

# %%
type(list_years)
# Out:
# list

# %%
years = 0
indexub = 0

list_years = list(years_exp.items())

while years < 5:      # keeps listing values, stops when the value is greater than 5, inclusively
  key, years = list_years[indexub]
  print(key, years)
  indexub +=1

# indexub is just randomly written
# Out:
# Luke 4
# Kennedy 2
# Johhny 3
# Kalish 2
# Josh 7

# %%
years = 0
index = 0

list_years = list(years_exp.items())

while years < 5:
  key, years = list_years[index]
  if years >=4:
    print(key, 'has', years, 'years', 'of', 'exp')
  index +=1
# Out:
# Luke has 4 years of exp
# Josh has 7 years of exp
